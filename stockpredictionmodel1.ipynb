# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyesh-ashok/stockpredictionmodel1/blob/main/stockpredictionmodel1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

df=yf.Ticker("AAPL")
df=df.history(period="max")
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098834    0.099264    0.098834    0.098834
# 1980-12-15 00:00:00-05:00    0.094108    0.094108    0.093678    0.093678
# 1980-12-16 00:00:00-05:00    0.087232    0.087232    0.086802    0.086802
# 1980-12-17 00:00:00-05:00    0.088951    0.089381    0.088951    0.088951
# 1980-12-18 00:00:00-05:00    0.091530    0.091959    0.091530    0.091530
# ...                               ...         ...         ...         ...
# 2024-12-18 00:00:00-05:00  252.160004  254.279999  247.740005  248.050003
# 2024-12-19 00:00:00-05:00  247.500000  252.000000  247.089996  249.789993
# 2024-12-20 00:00:00-05:00  248.039993  255.000000  245.690002  254.490005
# 2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997  255.270004
# 2024-12-24 00:00:00-05:00  255.490005  258.209991  255.289993  258.200012
#
#                               Volume  Dividends  Stock Splits
# Date
# 1980-12-12 00:00:00-05:00  469033600        0.0           0.0
# 1980-12-15 00:00:00-05:00  175884800        0.0           0.0
# 1980-12-16 00:00:00-05:00  105728000        0.0           0.0
# 1980-12-17 00:00:00-05:00   86441600        0.0           0.0
# 1980-12-18 00:00:00-05:00   73449600        0.0           0.0
# ...                              ...        ...           ...
# 2024-12-18 00:00:00-05:00   56774100        0.0           0.0
# 2024-12-19 00:00:00-05:00   60882300        0.0           0.0
# 2024-12-20 00:00:00-05:00  147495300        0.0           0.0
# 2024-12-23 00:00:00-05:00   40858800        0.0           0.0
# 2024-12-24 00:00:00-05:00   23234700        0.0           0.0
#
# [11101 rows x 7 columns]

# %%
del df["Dividends"]
del df["Stock Splits"]
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098834    0.099264    0.098834    0.098834
# 1980-12-15 00:00:00-05:00    0.094108    0.094108    0.093678    0.093678
# 1980-12-16 00:00:00-05:00    0.087232    0.087232    0.086802    0.086802
# 1980-12-17 00:00:00-05:00    0.088951    0.089381    0.088951    0.088951
# 1980-12-18 00:00:00-05:00    0.091530    0.091959    0.091530    0.091530
# ...                               ...         ...         ...         ...
# 2024-12-18 00:00:00-05:00  252.160004  254.279999  247.740005  248.050003
# 2024-12-19 00:00:00-05:00  247.500000  252.000000  247.089996  249.789993
# 2024-12-20 00:00:00-05:00  248.039993  255.000000  245.690002  254.490005
# 2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997  255.270004
# 2024-12-24 00:00:00-05:00  255.490005  258.209991  255.289993  258.200012
#
#                               Volume
# Date
# 1980-12-12 00:00:00-05:00  469033600
# 1980-12-15 00:00:00-05:00  175884800
# 1980-12-16 00:00:00-05:00  105728000
# 1980-12-17 00:00:00-05:00   86441600
# 1980-12-18 00:00:00-05:00   73449600
# ...                              ...
# 2024-12-18 00:00:00-05:00   56774100
# 2024-12-19 00:00:00-05:00   60882300
# 2024-12-20 00:00:00-05:00  147495300
# 2024-12-23 00:00:00-05:00   40858800
# 2024-12-24 00:00:00-05:00   23234700
#
# [11101 rows x 5 columns]

# %%
df.plot.line(y="Close",use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Calculated the target

# %%
df["Tom"]=df["Close"].shift(-1)
df["Target"]=(df["Tom"]>df["Close"]).astype(int)
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098834    0.099264    0.098834    0.098834
# 1980-12-15 00:00:00-05:00    0.094108    0.094108    0.093678    0.093678
# 1980-12-16 00:00:00-05:00    0.087232    0.087232    0.086802    0.086802
# 1980-12-17 00:00:00-05:00    0.088951    0.089381    0.088951    0.088951
# 1980-12-18 00:00:00-05:00    0.091530    0.091959    0.091530    0.091530
# ...                               ...         ...         ...         ...
# 2024-12-18 00:00:00-05:00  252.160004  254.279999  247.740005  248.050003
# 2024-12-19 00:00:00-05:00  247.500000  252.000000  247.089996  249.789993
# 2024-12-20 00:00:00-05:00  248.039993  255.000000  245.690002  254.490005
# 2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997  255.270004
# 2024-12-24 00:00:00-05:00  255.490005  258.209991  255.289993  258.200012
#
#                               Volume         Tom  Target
# Date
# 1980-12-12 00:00:00-05:00  469033600    0.093678       0
# 1980-12-15 00:00:00-05:00  175884800    0.086802       0
# 1980-12-16 00:00:00-05:00  105728000    0.088951       1
# 1980-12-17 00:00:00-05:00   86441600    0.091530       1
# 1980-12-18 00:00:00-05:00   73449600    0.097116       1
# ...                              ...         ...     ...
# 2024-12-18 00:00:00-05:00   56774100  249.789993       1
# 2024-12-19 00:00:00-05:00   60882300  254.490005       1
# 2024-12-20 00:00:00-05:00  147495300  255.270004       1
# 2024-12-23 00:00:00-05:00   40858800  258.200012       1
# 2024-12-24 00:00:00-05:00   23234700         NaN       0
#
# [11101 rows x 7 columns]

# %%
df=df.loc["1990-01-01":].copy()
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1990-01-02 00:00:00-05:00    0.248055    0.263888    0.246296    0.262129
# 1990-01-03 00:00:00-05:00    0.267408    0.267408    0.263888    0.263888
# 1990-01-04 00:00:00-05:00    0.269167    0.272685    0.262129    0.264769
# 1990-01-05 00:00:00-05:00    0.265648    0.269167    0.260370    0.265648
# 1990-01-08 00:00:00-05:00    0.263888    0.267408    0.260370    0.267408
# ...                               ...         ...         ...         ...
# 2024-12-18 00:00:00-05:00  252.160004  254.279999  247.740005  248.050003
# 2024-12-19 00:00:00-05:00  247.500000  252.000000  247.089996  249.789993
# 2024-12-20 00:00:00-05:00  248.039993  255.000000  245.690002  254.490005
# 2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997  255.270004
# 2024-12-24 00:00:00-05:00  255.490005  258.209991  255.289993  258.200012
#
#                               Volume         Tom  Target
# Date
# 1990-01-02 00:00:00-05:00  183198400    0.263888       1
# 1990-01-03 00:00:00-05:00  207995200    0.264769       1
# 1990-01-04 00:00:00-05:00  221513600    0.265648       1
# 1990-01-05 00:00:00-05:00  123312000    0.267408       1
# 1990-01-08 00:00:00-05:00  101572800    0.264769       0
# ...                              ...         ...     ...
# 2024-12-18 00:00:00-05:00   56774100  249.789993       1
# 2024-12-19 00:00:00-05:00   60882300  254.490005       1
# 2024-12-20 00:00:00-05:00  147495300  255.270004       1
# 2024-12-23 00:00:00-05:00   40858800  258.200012       1
# 2024-12-24 00:00:00-05:00   23234700         NaN       0
#
# [8813 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

model=RandomForestClassifier(n_estimators=100,min_samples_split=100,random_state=1)
train=df.iloc[:-100]
test=df.iloc[-100:]

predictors=["Close","Volume","Open","High","Low"]
model.fit(train[predictors],train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score,accuracy_score

preds=model.predict(test[predictors])
preds=pd.Series(preds,index=test.index)
precision_score(test["Target"],preds)
# Out:
# 0.61

# %%
combined=pd.concat([test["Target"],preds],axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
preds=model.predict(test[predictors])
accuracy_score(test["Target"],preds)
# Out:
# 0.61

# %%
def predict(train,test,predictors,model):
    model.fit(train[predictors],train["Target"])
    preds=model.predict(test[predictors])
    preds=pd.Series(preds,index=test.index,name="Predictions")
    combined=pd.concat([test["Target"],preds],axis=1)
    return combined

# %%
def backtest(data,model,predictors,start=2500,step=250):
    all_predictions=[]

    for i in range(start,data.shape[0],step):
        train=data.iloc[0:i].copy()
        test=data.iloc[i:(i+step)].copy()
        predictions=predict(train,test,predictors,model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions=backtest(df,model,predictors)
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    4305
# 1    2008
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5149402390438247

# %%
predictions["Target"].value_counts()/predictions.shape[0]
# Out:
# Target
# 1    0.523523
# 0    0.476477
# Name: count, dtype: float64

# %%
horizons=[2,5,60,250,1000]
new_predictors=[]
for horizon in horizons:
  rolling_averages=df.rolling(horizon).mean()

  ratio_column=f"Close_Ratio_{horizon}"
  df[ratio_column]=df["Close"]/rolling_averages["Close"]
  trend_column=f"Trend_{horizon}"
  df[trend_column]=df.shift(1).rolling(horizon).sum()["Target"]
  new_predictors+=[ratio_column,trend_column]

# %%
df=df.dropna()
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1993-12-14 00:00:00-05:00    0.214789    0.218461    0.212954    0.213871
# 1993-12-15 00:00:00-05:00    0.212954    0.218461    0.212954    0.218461
# 1993-12-16 00:00:00-05:00    0.216625    0.218461    0.212954    0.215707
# 1993-12-17 00:00:00-05:00    0.216625    0.218461    0.213871    0.216625
# 1993-12-20 00:00:00-05:00    0.214789    0.218461    0.207446    0.209281
# ...                               ...         ...         ...         ...
# 2024-12-17 00:00:00-05:00  250.080002  253.830002  249.779999  253.479996
# 2024-12-18 00:00:00-05:00  252.160004  254.279999  247.740005  248.050003
# 2024-12-19 00:00:00-05:00  247.500000  252.000000  247.089996  249.789993
# 2024-12-20 00:00:00-05:00  248.039993  255.000000  245.690002  254.490005
# 2024-12-23 00:00:00-05:00  254.770004  255.649994  253.449997  255.270004
#
#                               Volume         Tom  Target  Close_Ratio_2  \
# Date
# 1993-12-14 00:00:00-05:00  293664000    0.218461       1       0.993604
# 1993-12-15 00:00:00-05:00  123883200    0.215707       0       1.010615
# 1993-12-16 00:00:00-05:00  126369600    0.216625       1       0.993658
# 1993-12-17 00:00:00-05:00  145152000    0.209281       0       1.002123
# 1993-12-20 00:00:00-05:00  189033600    0.201939       0       0.982758
# ...                              ...         ...     ...            ...
# 2024-12-17 00:00:00-05:00   51356400  248.050003       0       1.004836
# 2024-12-18 00:00:00-05:00   56774100  249.789993       1       0.989173
# 2024-12-19 00:00:00-05:00   60882300  254.490005       1       1.003495
# 2024-12-20 00:00:00-05:00  147495300  255.270004       1       1.009320
# 2024-12-23 00:00:00-05:00   40858800  258.200012       1       1.001530
#
#                            Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 1993-12-14 00:00:00-05:00      1.0       0.978993      1.0        1.007241
# 1993-12-15 00:00:00-05:00      1.0       1.014492      2.0        1.025698
# 1993-12-16 00:00:00-05:00      1.0       1.005994      2.0        1.010468
# 1993-12-17 00:00:00-05:00      1.0       1.001698      3.0        1.011960
# 1993-12-20 00:00:00-05:00      1.0       0.974357      2.0        0.975652
# ...                            ...            ...      ...             ...
# 2024-12-17 00:00:00-05:00      2.0       1.016278      4.0        1.091488
# 2024-12-18 00:00:00-05:00      1.0       0.993265      4.0        1.066505
# 2024-12-19 00:00:00-05:00      1.0       0.998768      4.0        1.072167
# 2024-12-20 00:00:00-05:00      2.0       1.012412      4.0        1.090218
# 2024-12-23 00:00:00-05:00      2.0       1.012109      4.0        1.091399
#
#                            Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 1993-12-14 00:00:00-05:00      22.0         0.694753      111.0
# 1993-12-15 00:00:00-05:00      23.0         0.711547      111.0
# 1993-12-16 00:00:00-05:00      22.0         0.704569      110.0
# 1993-12-17 00:00:00-05:00      23.0         0.709636      110.0
# 1993-12-20 00:00:00-05:00      22.0         0.687598      110.0
# ...                             ...              ...        ...
# 2024-12-17 00:00:00-05:00      37.0         1.238376      139.0
# 2024-12-18 00:00:00-05:00      36.0         1.210567      139.0
# 2024-12-19 00:00:00-05:00      37.0         1.217726      140.0
# 2024-12-20 00:00:00-05:00      37.0         1.239144      141.0
# 2024-12-23 00:00:00-05:00      37.0         1.241415      142.0
#
#                            Close_Ratio_1000  Trend_1000
# Date
# 1993-12-14 00:00:00-05:00          0.637248       462.0
# 1993-12-15 00:00:00-05:00          0.651009       462.0
# 1993-12-16 00:00:00-05:00          0.642898       461.0
# 1993-12-17 00:00:00-05:00          0.645728       461.0
# 1993-12-20 00:00:00-05:00          0.623946       460.0
# ...                                     ...         ...
# 2024-12-17 00:00:00-05:00          1.523506       530.0
# 2024-12-18 00:00:00-05:00          1.489845       529.0
# 2024-12-19 00:00:00-05:00          1.499235       530.0
# 2024-12-20 00:00:00-05:00          1.526310       531.0
# 2024-12-23 00:00:00-05:00          1.529837       532.0
#
# [7812 rows x 17 columns]

# %%
model=RandomForestClassifier(n_estimators=200,min_samples_split=50,random_state=1)
# predictions=backtest(df,model,new_predictors)

# %%
def predict(train,test,predictors,model):
    model.fit(train[predictors],train["Target"])
    preds=model.predict_proba(test[predictors])[:,1]
    preds[preds>=.6]=1
    preds[preds<.6]=0
    preds=pd.Series(preds,index=test.index,name="Predictions")
    combined=pd.concat([test["Target"],preds],axis=1)
    return combined

# %%
predictions=backtest(df,model,new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    4761
# 1.0     551
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5335753176043557

# %%
combined=pd.concat([test["Target"],predictions["Predictions"]],axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>
